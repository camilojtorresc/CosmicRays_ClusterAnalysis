# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import os

# %%
#Path of the file with the data of particles
os.chdir(r'/home/user/Documents/BUAP/Estancia/CosmicRayReco/MCAnalysis/ClusterAnalysis/Data')

# %%
#File with summary of Showers
Showers = pd.read_csv(r'DAT000001_showers.txt',delimiter='\t')

# %%
#File with information of all particles at observation level
Particles = pd.read_csv('DAT000001_particles.txt',delimiter='\t')

# %%
#Statistics of the data frame with summary of showers 
Showers.describe()
# Out:
#          N. Shower  Energy (GeV)  Zfirst (km)    Theta (°)      Phi (°)  \
# count  3291.000000   3291.000000  3291.000000  3291.000000  3291.000000
# mean   5023.674263     27.315321    19.931555    16.543894    -0.372091
# std    2906.218246     17.970448     7.705788     6.123047   103.288679
# min       2.000000     10.001600     4.402460     0.416042  -179.986000
# 25%    2497.500000     14.433050    14.720400    12.259950   -88.951200
# 50%    5007.000000     21.047800    18.611900    17.384900    -1.282500
# 75%    7570.000000     33.810350    23.793900    21.772350    87.615800
# max    9992.000000     99.982900    70.343800    25.793100   179.910000
#
#        N. Particles
# count   3291.000000
# mean       1.983895
# std        2.399477
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       46.000000

# %%
#Definition of a box which contain all the particles of the simulation

det_s_x = 1.0 # detector size in x axis (m)
det_s_y = 1.0 # detector size in y axis (m)

# %%
#Add two new columns that will contain the positions of the cells in the mesh
Particles['DetPosx'] = 0; Particles['DetPosy'] = 0
#Add two new columns that will contain the positions of the particles inside the cells
Particles['CoorDetx'] = 0; Particles['CoorDety'] = 0

# %%
#The values in the 'DetPosx' and 'DetPosy' columns will be replaced by the rounded values 
#of the positions of the particles, this will define the position of the cell
#For the X axis
Particles.loc[Particles['x (m)'] > 0,'DetPosx'] = np.ceil(Particles.loc[Particles['x (m)'] > 0,'x (m)'])
Particles.loc[Particles['x (m)'] < 0,'DetPosx'] = np.floor(Particles.loc[Particles['x (m)'] < 0,'x (m)'])
#For the Y axis
Particles.loc[Particles['y (m)'] > 0,'DetPosy'] = np.ceil(Particles.loc[Particles['y (m)'] > 0,'y (m)'])
Particles.loc[Particles['y (m)'] < 0,'DetPosy'] = np.floor(Particles.loc[Particles['y (m)'] < 0,'y (m)'])

# %%
#The values in the 'CoorDetx' and 'CoorDety' columns will be replaced by the division remainder values
#of the positions of the particles divided by the size of the detector, this will define the position 
#in the cell
#For the X axis
Particles.loc[Particles['x (m)'] > 0,'CoorDetx'] = (Particles.loc[Particles['x (m)'] > 0,'x (m)'] % det_s_x) - \
det_s_x/2
Particles.loc[Particles['x (m)'] < 0,'CoorDetx'] = -(-Particles.loc[Particles['x (m)'] < 0,'x (m)'] % det_s_x) + \
det_s_x/2
#For the Y axis
Particles.loc[Particles['y (m)'] > 0,'CoorDety'] = Particles.loc[Particles['y (m)'] > 0,'y (m)'] % det_s_x - \
det_s_y/2
Particles.loc[Particles['y (m)'] < 0,'CoorDety'] = -(-Particles.loc[Particles['y (m)'] < 0,'y (m)'] % det_s_y) + \
det_s_y/2
#Add a new column which will contain the number of cluster 
Particles['Ncluster'] = 0
#Note: This cell could produce a warning, apparently it is a bug that may be solve on future versions 
#of pandas but it is not an error of the code nor the commands
# Out:
# /tmp/ipykernel_12817/3721817253.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.09  -0.263 -0.065 ...  0.331 -0.21   0.132]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Particles.loc[Particles['x (m)'] > 0,'CoorDetx'] = (Particles.loc[Particles['x (m)'] > 0,'x (m)'] % det_s_x) - \
# /tmp/ipykernel_12817/3721817253.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.202  -0.34    0.029  ...  0.456  -0.0971 -0.34  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Particles.loc[Particles['y (m)'] > 0,'CoorDety'] = Particles.loc[Particles['y (m)'] > 0,'y (m)'] % det_s_x - \

# %%
Particles
# Out:
#       N. sh  P. id     x (m)      y (m)   t (ns)  px (GeV/c)  py (GeV/c)  \
# 0         2      5  -201.900   420.2980  46566.3    0.188691    0.222028
# 1         5      1  2734.410  1849.1600  41688.3    0.176521    0.060548
# 2         5      6   651.237  -532.5820  36718.8    1.175570    0.333113
# 3         5     13 -2962.930 -2115.3400  44320.1   -0.000764    0.054818
# 4         8      5   546.435   274.5290  45642.4    0.482937   -0.113526
# ...     ...    ...       ...        ...      ...         ...         ...
# 6524   9992      5   785.352   -92.9172  48104.9    1.464110   -1.455900
# 6525   9992      1   453.560    99.4029  47603.6    0.019707   -0.018949
# 6526   9992      1   581.831   -74.4873  47876.1    0.033238   -0.031373
# 6527   9992      3   610.290   -93.9667  47932.3    0.026325   -0.051130
# 6528   9992      6   445.632  1143.1600  46765.1    0.731540   -0.339325
#
#       pz (GeV/c)  Psq (GeV)  ek (GeV)   zha (°)  aza (°)  DetPosx  DetPosy  \
# 0       0.985500   1.056110  0.927432  16.47110  49.6405     -202      421
# 1       0.232008   0.088653  0.297747  38.81170  18.9323     2735     1850
# 2       2.418140   7.340320  2.605700  26.80680  15.8208      652     -533
# 3       0.811598   0.661697  0.303206   3.86449  90.7981    -2963    -2116
# 4       2.103300   4.669980  2.057940  13.27170 -13.2286      547      275
# ...          ...        ...       ...       ...      ...      ...      ...
# 6524    4.051300  20.676300  4.442690  27.00580 -44.8389      786      -93
# 6525    0.077221   0.006711  0.081918  19.49600 -43.8769      454      100
# 6526    0.091648   0.010488  0.102413  26.50560 -43.3468      582      -75
# 6527    0.071720   0.008451  0.091420  38.72450 -62.7579      611      -94
# 6528    2.140140   5.230480  2.183810  20.64650 -24.8842      446     1144
#
#       CoorDetx  CoorDety  Ncluster
# 0       -0.400   -0.2020         0
# 1       -0.090   -0.3400         0
# 2       -0.263   -0.0820         0
# 3       -0.430    0.1600         0
# 4       -0.065    0.0290         0
# ...        ...       ...       ...
# 6524    -0.148   -0.4172         0
# 6525     0.060   -0.0971         0
# 6526     0.331    0.0127         0
# 6527    -0.210   -0.4667         0
# 6528     0.132   -0.3400         0
#
# [6529 rows x 17 columns]

# %%
#Define a function to find the clusters of particles with arguments number of cluster (ith_clust) and shower number (Sh_n)
def Clusters(ith_clust, Sh_n):
    
    # Transform the columns of the particle data frame with the position of the detector into a list
    x_pos = Sh_n['DetPosx'].tolist()
    y_pos = Sh_n['DetPosy'].tolist()
    
    # Create an empty set
    unique_pairs = set()

    # Iterate over the pairs of x and y using zip
    for xi, yi in zip(x_pos, y_pos):
        pair = (xi, yi)

        # Check if the pair is already in the set
        if pair not in unique_pairs:
            # If not, add it to the set
            unique_pairs.add(pair)

            # Extract the particles index by comparing it with the x, y position in the data frame
            p_index_clust = Sh_n.index[ (Sh_n['DetPosx'] == xi) & (Sh_n['DetPosy'] == yi) ].tolist()
            
            # Replacte the cluster position of the particle for the cluster id
            for j in range(len(p_index_clust)):
                Sh_n.at[p_index_clust[j],'Ncluster'] = ith_clust

            ith_clust = ith_clust+1 # Next Cluster
    
    return Sh_n, ith_clust

# %%
# %%time
ith_clust = 1 # First cluster

# ids. of all clusters in the data set
cluster_ids = Showers["N. Shower"].tolist() 

# Run over all the showers
for ith_shower in cluster_ids:
    Sh_n, ith_clust = Clusters(ith_clust, Particles[Particles['N. sh']==ith_shower]) 
    Particles.loc[Particles['N. sh']==ith_shower, :] = Sh_n
# Out:
# CPU times: user 37.7 s, sys: 16.5 ms, total: 37.7 s
# Wall time: 37.7 s

# %%
# Check if there are particles that are not counted
Particles[Particles["Ncluster"]==0]
# Out:
# Empty DataFrame
# Columns: [N. sh, P. id, x (m), y (m), t (ns), px (GeV/c), py (GeV/c), pz (GeV/c), Psq (GeV), ek (GeV), zha (°), aza (°), DetPosx, DetPosy, CoorDetx, CoorDety, Ncluster]
# Index: []

# %%
# Number of the cluster with the maximum number of particles
df_sn = Particles[Particles["Ncluster"]!=0]
print(df_sn["Ncluster"].value_counts().idxmax())
# Out:
# 4808

# %%
# Summary of the cluster with the maximum number of particles
Particles[Particles["Ncluster"]==4808].describe()
# Out:
#         N. sh     P. id        x (m)        y (m)        t (ns)  px (GeV/c)  \
# count     4.0  4.000000     4.000000     4.000000      4.000000    4.000000
# mean   7556.0  1.750000 -1006.490000  1931.350000  55955.100000   -0.100733
# std       0.0  0.957427     0.110151     0.198494      0.141421    0.087137
# min    7556.0  1.000000 -1006.620000  1931.060000  55954.900000   -0.226749
# 25%    7556.0  1.000000 -1006.560000  1931.307500  55955.050000   -0.114874
# 50%    7556.0  1.500000 -1006.480000  1931.420000  55955.150000   -0.075016
# 75%    7556.0  2.250000 -1006.410000  1931.462500  55955.200000   -0.060875
# max    7556.0  3.000000 -1006.380000  1931.500000  55955.200000   -0.026151
#
#        py (GeV/c)  pz (GeV/c)  Psq (GeV)  ek (GeV)    zha (°)     aza (°)  \
# count    4.000000    4.000000   4.000000  4.000000   4.000000    4.000000
# mean     0.035492    0.339599   0.196370  0.355748  17.349425  160.691000
# std      0.031560    0.290275   0.293296  0.304502   0.228002    1.165675
# min      0.009392    0.089501   0.008782  0.093715  17.090100  159.852000
# 25%      0.020787    0.210627   0.053914  0.220378  17.208225  160.146750
# 50%      0.025583    0.254962   0.071311  0.266749  17.348300  160.247500
# 75%      0.040289    0.383934   0.213767  0.402120  17.489500  160.791750
# max      0.081410    0.758969   0.634077  0.795779  17.611000  162.417000
#
#        DetPosx  DetPosy  CoorDetx  CoorDety  Ncluster
# count      4.0      4.0  4.000000  4.000000       4.0
# mean   -1007.0   1932.0  0.010000 -0.150000    4808.0
# std        0.0      0.0  0.110151  0.198494       0.0
# min    -1007.0   1932.0 -0.120000 -0.440000    4808.0
# 25%    -1007.0   1932.0 -0.060000 -0.192500    4808.0
# 50%    -1007.0   1932.0  0.020000 -0.080000    4808.0
# 75%    -1007.0   1932.0  0.090000 -0.037500    4808.0
# max    -1007.0   1932.0  0.120000  0.000000    4808.0

# %%
Particles[Particles["Ncluster"]==4808]
# Out:
#       N. sh  P. id    x (m)    y (m)   t (ns)  px (GeV/c)  py (GeV/c)  \
# 4860   7556      1 -1006.62  1931.39  55955.2   -0.026151    0.009392
# 4861   7556      1 -1006.42  1931.45  55955.1   -0.072449    0.026581
# 4862   7556      3 -1006.38  1931.06  55954.9   -0.077582    0.024585
# 4863   7556      2 -1006.54  1931.50  55955.2   -0.226749    0.081410
#
#       pz (GeV/c)  Psq (GeV)  ek (GeV)  zha (°)  aza (°)  DetPosx  DetPosy  \
# 4860    0.089501   0.008782  0.093715  17.2476  160.245    -1007     1932
# 4861    0.251003   0.068958  0.262599  17.0901  159.852    -1007     1932
# 4862    0.258922   0.073664  0.270900  17.4490  162.417    -1007     1932
# 4863    0.758969   0.634077  0.795779  17.6110  160.250    -1007     1932
#
#       CoorDetx  CoorDety  Ncluster
# 4860     -0.12     -0.11      4808
# 4861      0.08     -0.05      4808
# 4862      0.12     -0.44      4808
# 4863     -0.04      0.00      4808

# %%
#Plot the cell with the maximum number of particles
cx = Particles.loc[Particles["Ncluster"]==4808,'DetPosx'].iloc[0]
cy = Particles.loc[Particles["Ncluster"]==4808,'DetPosy'].iloc[0]
Mx = Particles.loc[Particles["Ncluster"]==4808,'CoorDetx']
My = Particles.loc[Particles["Ncluster"]==4808,'CoorDety']
plt.scatter(Mx,My)
plt.title('Cell: X=%i, Y=%i'%(cx,cy))
plt.xlabel('X (m)')
plt.ylabel('Y (m)')
#Cell for detector of 1 m^2
plt.axis([-0.5,0.5,-0.5,0.5])
#Cell for detector of 0.30 x 0.30 m^2
#plt.axis([-0.15,0.15,-0.15,0.15])
plt.grid(True)
